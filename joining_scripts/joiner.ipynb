# %%
import pandas as pd

# %%
land_cover_2013 = pd.read_csv('land_cover_2013.csv')
land_cover_2016 = pd.read_csv('land_cover_2016.csv')
land_cover_2004 = pd.read_csv('land_cover_2004.csv')
land_cover_2008 = pd.read_csv('land_cover_2008.csv')
#zonal_2016 = pd.read_csv('output_zonal_2016.csv')
election = pd.read_csv('countypres_2000-2016.csv')

# %%
election
# Out:
#        year    state state_po       county    FIPS     office  \
# 0      2000  Alabama       AL      Autauga  1001.0  President
# 1      2000  Alabama       AL      Autauga  1001.0  President
# 2      2000  Alabama       AL      Autauga  1001.0  President
# 3      2000  Alabama       AL      Autauga  1001.0  President
# 4      2000  Alabama       AL      Baldwin  1003.0  President
# ...     ...      ...      ...          ...     ...        ...
# 50519  2016   Alaska       AK  District 40  2040.0  President
# 50520  2016   Alaska       AK  District 40  2040.0  President
# 50521  2016   Alaska      NaN  District 99  2099.0  President
# 50522  2016   Alaska      NaN  District 99  2099.0  President
# 50523  2016   Alaska      NaN  District 99  2099.0  President
#
#              candidate       party  candidatevotes  totalvotes   version
# 0              Al Gore    democrat          4942.0       17208  20191203
# 1       George W. Bush  republican         11993.0       17208  20191203
# ...

# %%
election1 = election[['party','candidatevotes']]

# %%
election1.transpose()
# Out:
#                    0           1      2     3         4           5      \
# party           democrat  republican  green   NaN  democrat  republican
# candidatevotes      4942       11993    160   113     13997       40872
#
#                 6     7         8           9      ... 50514     50515  \
# party           green   NaN  democrat  republican  ...   NaN  democrat
# candidatevotes   1033   578      5188        5096  ...  1194      3142
#
#                      50516 50517     50518       50519 50520     50521  \
# party           republican   NaN  democrat  republican   NaN  democrat
# candidatevotes        1405  1092      2338        1377   895       274
#
#                      50522 50523
# party           republican   NaN
# candidatevotes          40    28
#
# [2 rows x 50524 columns]

# %%
election['dem_votes'] = election.loc[election['party'] == 'democrat', 'candidatevotes']

# %%
election
# Out:
#        year    state state_po       county    FIPS     office  \
# 0      2000  Alabama       AL      Autauga  1001.0  President
# 1      2000  Alabama       AL      Autauga  1001.0  President
# 2      2000  Alabama       AL      Autauga  1001.0  President
# 3      2000  Alabama       AL      Autauga  1001.0  President
# 4      2000  Alabama       AL      Baldwin  1003.0  President
# ...     ...      ...      ...          ...     ...        ...
# 50519  2016   Alaska       AK  District 40  2040.0  President
# 50520  2016   Alaska       AK  District 40  2040.0  President
# 50521  2016   Alaska      NaN  District 99  2099.0  President
# 50522  2016   Alaska      NaN  District 99  2099.0  President
# 50523  2016   Alaska      NaN  District 99  2099.0  President
#
#              candidate       party  candidatevotes  totalvotes   version  \
# 0              Al Gore    democrat          4942.0       17208  20191203
# ...

# %%
res = election.groupby(['FIPS', 'year'])['candidatevotes'].sum().reset_index()

# %%
res
# Out:
#           FIPS  year  candidatevotes
# 0       1001.0  2000         17208.0
# 1       1001.0  2004         20081.0
# 2       1001.0  2008         23641.0
# 3       1001.0  2012         23932.0
# 4       1001.0  2016         24973.0
# ...        ...   ...             ...
# 15769  56045.0  2000          3060.0
# 15770  56045.0  2004          3392.0
# 15771  56045.0  2008          3414.0
# 15772  56045.0  2012          3359.0
# 15773  56045.0  2016          3526.0
#
# [15774 rows x 3 columns]

# %%
election = election.dropna()

# %%
election['democrat'] = election['party'] =='democrat'
# Out:
# /Users/timdowling/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
election
# Out:
#        year    state state_po       county    FIPS     office  \
# 0      2000  Alabama       AL      Autauga  1001.0  President
# 1      2000  Alabama       AL      Autauga  1001.0  President
# 2      2000  Alabama       AL      Autauga  1001.0  President
# 4      2000  Alabama       AL      Baldwin  1003.0  President
# 5      2000  Alabama       AL      Baldwin  1003.0  President
# ...     ...      ...      ...          ...     ...        ...
# 50513  2016   Alaska       AK  District 38  2038.0  President
# 50515  2016   Alaska       AK  District 39  2039.0  President
# 50516  2016   Alaska       AK  District 39  2039.0  President
# 50518  2016   Alaska       AK  District 40  2040.0  President
# 50519  2016   Alaska       AK  District 40  2040.0  President
#
#              candidate       party  candidatevotes  totalvotes   version  \
# 0              Al Gore    democrat          4942.0       17208  20191203
# ...

# %%
res = election.groupby(['democrat', 'FIPS'])['candidatevotes'].mean().reset_index()
res
# Out:
#       democrat     FIPS  candidatevotes
# 0        False   1001.0    13383.833333
# 1        False   1003.0    49174.333333
# 2        False   1005.0     4651.833333
# 3        False   1007.0     4821.500000
# 4        False   1009.0    15702.000000
# ...        ...      ...             ...
# 6303      True  56037.0     4899.200000
# 6304      True  56039.0     6198.000000
# 6305      True  56041.0     1722.400000
# 6306      True  56043.0      805.800000
# 6307      True  56045.0      481.600000
#
# [6308 rows x 3 columns]

# %%
election['dem_votes'] = election[election.democrat].groupby('party')['candidatevotes']
election
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-7c6f5f8817fe> in <module>
# ----> 1 election['dem_votes'] = election[election.democrat].groupby('party')['candidatevotes']
#       2 election
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
# ...

# %%
total_votes = election[['FIPS']]\
.groupby(['party','totalvotes']).sum()
total_votes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-357bc49bd62c> in <module>
#       1 total_votes = election[['FIPS']]\
# ----> 2 .groupby(['party','totalvotes']).sum()
#       3 total_votes
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6519             squeeze=squeeze,
#    6520             observed=observed,
# -> 6521             dropna=dropna,
#    6522         )
#    6523
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
#     532                 mutated=self.mutated,
# --> 533                 dropna=self.dropna,
#     534             )
# ...

# %%
def f(row):
    dem = []
    rep = []
    if row['party'] == 'democrat':
        dem.append(row['candidatevotes'])
    else:
        rep.append(row['candidatevotes'])
    return dem, rep

election.apply(f, axis=1)
# Out:
# 0         ([4942.0], [])
# 1        ([], [11993.0])
# 2          ([], [160.0])
# 3          ([], [113.0])
# 4        ([13997.0], [])
#               ...
# 50519     ([], [1377.0])
# 50520      ([], [895.0])
# 50521      ([274.0], [])
# 50522       ([], [40.0])
# 50523       ([], [28.0])
# Length: 50524, dtype: object

# %%
dem
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3e26f0210ab7> in <module>
# ----> 1 dem
#
# NameError: name 'dem' is not defined

# %%
land_cover_test = pd.DataFrame(land_cover_test)
land_cover_test = zonal_2016.rename(columns={"HISTO_11": "open_water", "HISTO_12":"ice_snow", "HISTO_21":"open_space","HISTO_22":"low_intensity","HISTO_23":"medium_intensity","HISTO_24":"high_intensity","HISTO_31":"barren_land","HISTO_41":"deciduous_forest","HISTO_42":"evergreen_forest","HISTO_43":"mixed_forest","HISTO_51":"dwarf_scrub","HISTO_52":"shrub_scrub","HISTO_71":"grassland","HISTO_72":"sedge","HISTO_73":'lichens',"HISTO_74":"moss","HISTO_81":"pasture_hay","HISTO_82":"cultivated_crops","HISTO_90":"woody_wetlands","HISTO_95":"emergent_wetlands"})
land_cover_test
# Out:
#       STATEFP  COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD  LSAD  \
# 0          31        39    835841  31039     Cuming     Cuming County     6
# 1          53        69   1513275  53069  Wahkiakum  Wahkiakum County     6
# 2          35        11    933054  35011    De Baca    De Baca County     6
# 3          31       109    835876  31109  Lancaster  Lancaster County     6
# 4          31       129    835886  31129   Nuckolls   Nuckolls County     6
# ...       ...       ...       ...    ...        ...               ...   ...
# 3229       13       123    351260  13123     Gilmer     Gilmer County     6
# 3230       27       135    659513  27135     Roseau     Roseau County     6
# 3231       28        89    695768  28089    Madison    Madison County     6
# 3232       48       227   1383899  48227     Howard     Howard County     6
# 3233       54        99   1550056  54099      Wayne      Wayne County     6
#
# ...

# %%
land_cover_test = land_cover_test[['']]

# %%
land_cover_test['total_cover']= land_cover_test.sum(axis=1)
land_cover_test
# Out:
#       STATEFP  COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD  LSAD  \
# 0          31        39    835841  31039     Cuming     Cuming County     6
# 1          53        69   1513275  53069  Wahkiakum  Wahkiakum County     6
# 2          35        11    933054  35011    De Baca    De Baca County     6
# 3          31       109    835876  31109  Lancaster  Lancaster County     6
# 4          31       129    835886  31129   Nuckolls   Nuckolls County     6
# ...       ...       ...       ...    ...        ...               ...   ...
# 3229       13       123    351260  13123     Gilmer     Gilmer County     6
# 3230       27       135    659513  27135     Roseau     Roseau County     6
# 3231       28        89    695768  28089    Madison    Madison County     6
# 3232       48       227   1383899  48227     Howard     Howard County     6
# 3233       54        99   1550056  54099      Wayne      Wayne County     6
#
# ...

# %%
test = 13067+0+52204+15637+2004+718+1393+19663+1+89+68+118980+14743+1389374+17213+8579
test2= 63177+0+41183+7690+1088+153+1712+46373+386822+36606+93754+52338+22243+857+19767+51292
test2
# Out:
# 825055

# %%
7.618780e
# Out:
#   File "<ipython-input-77-66a6e8ae3404>", line 1
#     7.618780e
#             ^
# SyntaxError: invalid syntax

# %%
land_cover_test[land_cover_test.columns[-18:]]
# Out:
#       open_water  ice_snow  open_space  low_intensity  medium_intensity  \
# 0          13067         0       52204          15637              2004
# 1          63177         0       41183           7690              1088
# 2          13414         0       23718           3460               771
# 3          33960         0      101674         129899             68004
# 4           7583         0       51057           9589              1423
# ...          ...       ...         ...            ...               ...
# 3229       14000         0       89431           9820              3619
# 3230       16927         0      109258          27277              3503
# 3231       76684         0      113483          61177             31272
# 3232       14288         0       96926          40844              8600
# 3233       18676         0       53093          31921             12544
#
#       high_intensity  barren_land  deciduous_forest  evergreen_forest  \
# ...

# %%
land_cover_test['real_totals']= land_cover_test[land_cover_test.columns[-16:]].sum(axis=1)
land_cover_test
# Out:
#       STATEFP  COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD  LSAD  \
# 0          31        39    835841  31039     Cuming     Cuming County     6
# 1          53        69   1513275  53069  Wahkiakum  Wahkiakum County     6
# 2          35        11    933054  35011    De Baca    De Baca County     6
# 3          31       109    835876  31109  Lancaster  Lancaster County     6
# 4          31       129    835886  31129   Nuckolls   Nuckolls County     6
# ...       ...       ...       ...    ...        ...               ...   ...
# 3229       13       123    351260  13123     Gilmer     Gilmer County     6
# 3230       27       135    659513  27135     Roseau     Roseau County     6
# 3231       28        89    695768  28089    Madison    Madison County     6
# 3232       48       227   1383899  48227     Howard     Howard County     6
# 3233       54        99   1550056  54099      Wayne      Wayne County     6
#
# ...

# %%
non_zero = []

test = land_cover_test['real_totals']

for i in test:
    if i != 0:
        non_zero.append(i)
len(non_zero)
# Out:
# 3108

# %%
test
# Out:
# 0       1.640666e+06
# 1       7.618780e+05
# 2       6.704278e+06
# 3       2.401706e+06
# 4       1.649487e+06
#             ...
# 3229    3.354550e+09
# 3230    1.306129e+10
# 3231    5.776348e+09
# 3232    7.040375e+09
# 3233    3.989864e+09
# Name: real_totals, Length: 3234, dtype: float64

# %%
land_cover_test['total_cover']= land_cover_test.iloc[-16:].sum(axis=1)
land_cover_test
# Out:
#       STATEFP  COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD  LSAD  \
# 0          31        39    835841  31039     Cuming     Cuming County     6
# 1          53        69   1513275  53069  Wahkiakum  Wahkiakum County     6
# 2          35        11    933054  35011    De Baca    De Baca County     6
# 3          31       109    835876  31109  Lancaster  Lancaster County     6
# 4          31       129    835886  31129   Nuckolls   Nuckolls County     6
# ...       ...       ...       ...    ...        ...               ...   ...
# 3229       13       123    351260  13123     Gilmer     Gilmer County     6
# 3230       27       135    659513  27135     Roseau     Roseau County     6
# 3231       28        89    695768  28089    Madison    Madison County     6
# 3232       48       227   1383899  48227     Howard     Howard County     6
# 3233       54        99   1550056  54099      Wayne      Wayne County     6
#
# ...

# %%
low_intensity = land_cover_test['low_intensity']
low_intensity = list(low_intensity)

open_space = land_cover_test['open_space']
open_space = list(open_space)

medium_intensity = land_cover_test['medium_intensity']
medium_intensity = list(medium_intensity)

high_intensity = land_cover_test['high_intensity']
high_intensity = list(high_intensity)

# %%
zonal_2016
# Out:
#       STATEFP  COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD  LSAD  \
# 0          31        39    835841  31039     Cuming     Cuming County     6
# 1          53        69   1513275  53069  Wahkiakum  Wahkiakum County     6
# 2          35        11    933054  35011    De Baca    De Baca County     6
# 3          31       109    835876  31109  Lancaster  Lancaster County     6
# 4          31       129    835886  31129   Nuckolls   Nuckolls County     6
# ...       ...       ...       ...    ...        ...               ...   ...
# 3229       13       123    351260  13123     Gilmer     Gilmer County     6
# 3230       27       135    659513  27135     Roseau     Roseau County     6
# 3231       28        89    695768  28089    Madison    Madison County     6
# 3232       48       227   1383899  48227     Howard     Howard County     6
# 3233       54        99   1550056  54099      Wayne      Wayne County     6
#
# ...

# %%
land_cover_2004.append(land_cover_2008, ignore_index=True)
# Out:
#       STATEFP  COUNTYFP          NAMELSAD  pct_sub_2004  pct_urban_2004  \
# 0          53        69  Wahkiakum County      0.060512        0.000181
# 1          35        11    De Baca County      0.004146        0.000027
# 2          31       109  Lancaster County      0.111214        0.010180
# 3          31       129   Nuckolls County      0.037214        0.000270
# 4          46        99  Minnehaha County      0.092424        0.006433
# ...       ...       ...               ...           ...             ...
# 4586       13       123     Gilmer County           NaN             NaN
# 4587       27       135     Roseau County           NaN             NaN
# 4588       28        89    Madison County           NaN             NaN
# 4589       48       227     Howard County           NaN             NaN
# 4590       54        99      Wayne County           NaN             NaN
#
#       pct_forest_2004  pct_agri_2004  unique  pct_sub_2008  pct_urban_2008  \
# ...

# %%
land_cover_2013
# Out:
#       STATEFP  COUNTYFP          NAMELSAD  pct_sub_2013  pct_urban_2013  \
# 0          31        39     Cuming County      0.041952        0.000417
# 1          53        69  Wahkiakum County      0.060537        0.000184
# 2          35        11    De Baca County      0.004160        0.000027
# 3          31       109  Lancaster County      0.121389        0.012194
# 4          31       129   Nuckolls County      0.037256        0.000286
# ...       ...       ...               ...           ...             ...
# 2455       40        47   Garfield County      0.061867        0.002789
# 2456       53        59   Skamania County      0.040037        0.000482
# 2457       26        91    Lenawee County      0.085797        0.003402
# 2458       27       135     Roseau County      0.028896        0.000172
# 2459       54        99      Wayne County      0.063596        0.001595
#
#       pct_forest_2013  pct_agri_2013  unique
# 0            0.011971       0.847563      15
# ...

# %%
pd.concat([land_cover_2013, land_cover_2016], sort=True)
# Out:
#       COUNTYFP     NAME          NAMELSAD  STATEFP  pct_agri_2013  \
# 0           39      NaN     Cuming County       31       0.847563
# 1           69      NaN  Wahkiakum County       53       0.028020
# 2           11      NaN    De Baca County       35       0.006783
# 3          109      NaN  Lancaster County       31       0.564299
# 4          129      NaN   Nuckolls County       31       0.604279
# ...        ...      ...               ...      ...            ...
# 2192       123   Gilmer     Gilmer County       13            NaN
# 2193       135   Roseau     Roseau County       27            NaN
# 2194        89  Madison    Madison County       28            NaN
# 2195       227   Howard     Howard County       48            NaN
# 2196        99    Wayne      Wayne County       54            NaN
#
#       pct_agri_2016  pct_forest_2013  pct_forest_2016  pct_sub_2013  \
# 0               NaN         0.011971              NaN      0.041952
# ...

# %%
bungus = pd.merge(land_cover_2013, land_cover_2016)
bungus
# Out:
#       STATEFP  COUNTYFP          NAMELSAD  pct_sub_2013  pct_urban_2013  \
# 0          35        11    De Baca County      0.004160        0.000027
# 1          31       129   Nuckolls County      0.037256        0.000286
# 2          46        99  Minnehaha County      0.099460        0.007728
# 3           6        91     Sierra County      0.014654        0.000073
# 4          39        63    Hancock County      0.099549        0.005606
# ...       ...       ...               ...           ...             ...
# 1628       40        47   Garfield County      0.061867        0.002789
# 1629       53        59   Skamania County      0.040037        0.000482
# 1630       26        91    Lenawee County      0.085797        0.003402
# 1631       27       135     Roseau County      0.028896        0.000172
# 1632       54        99      Wayne County      0.063596        0.001595
#
#       pct_forest_2013  pct_agri_2013  unique       NAME  pct_sub_2016  \
# ...

# %%
test = land_cover_2004 
test
# Out:
#       STATEFP  COUNTYFP          NAMELSAD  pct_sub_2004  pct_urban_2004  \
# 0          53        69  Wahkiakum County      0.060512        0.000181
# 1          35        11    De Baca County      0.004146        0.000027
# 2          31       109  Lancaster County      0.111214        0.010180
# 3          31       129   Nuckolls County      0.037214        0.000270
# 4          46        99  Minnehaha County      0.092424        0.006433
# ...       ...       ...               ...           ...             ...
# 2466       21       233    Webster County      0.050831        0.000857
# 2467       40        47   Garfield County      0.060792        0.002537
# 2468       13       123     Gilmer County      0.079974        0.000556
# 2469       28        89    Madison County      0.071265        0.001296
# 2470       54        99      Wayne County      0.062861        0.001468
#
#       pct_forest_2004  pct_agri_2004  unique
# 0            0.548271       0.028291      15
# ...

# %%
bungus =  pd.wide_to_long(test, ["pct"], i="NAMELSAD", j="year_land")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-a45bdd0c31f5> in <module>
# ----> 1 bungus =  pd.wide_to_long(test, ["pct"], i="NAMELSAD", j="year_land")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/melt.py in wide_to_long(df, stubnames, i, j, sep, suffix)
#     473
#     474     if df[i].duplicated().any():
# --> 475         raise ValueError("the id variables need to uniquely identify each row")
#     476
#     477     value_vars = [get_var_names(df, stub, sep, suffix) for stub in stubnames]
#
# ValueError: the id variables need to uniquely identify each row

# %%
pd.melt(test, id_vars='NAMELSAD', value_vars=["pct_sub_2004"])
# Out:
#               NAMELSAD      variable     value
# 0     Wahkiakum County  pct_sub_2004  0.060512
# 1       De Baca County  pct_sub_2004  0.004146
# 2     Lancaster County  pct_sub_2004  0.111214
# 3      Nuckolls County  pct_sub_2004  0.037214
# 4     Minnehaha County  pct_sub_2004  0.092424
# ...                ...           ...       ...
# 2466    Webster County  pct_sub_2004  0.050831
# 2467   Garfield County  pct_sub_2004  0.060792
# 2468     Gilmer County  pct_sub_2004  0.079974
# 2469    Madison County  pct_sub_2004  0.071265
# 2470      Wayne County  pct_sub_2004  0.062861
#
# [2471 rows x 3 columns]

# %%
land_cover = land_cover.rename(columns={"NAMELSAD": "county_name"})

# %%
land_cover.head()
# Out:
#    STATEFP  COUNTYFP       NAME       county_name  pct_sub_2016  \
# 0       35        11    De Baca    De Baca County      0.004161
# 1       31       129   Nuckolls   Nuckolls County      0.037457
# 2       46        99  Minnehaha  Minnehaha County      0.101924
# 3        6        91     Sierra     Sierra County      0.014658
# 4       39        63    Hancock    Hancock County      0.099926
#
#    pct_urban_2016  pct_forest_2016  pct_agri_2016  unique
# 0        0.000029         0.000017       0.007330      13
# 1        0.000296         0.026473       0.607295      14
# 2        0.008316         0.013281       0.812395      15
# 3        0.000073         0.647802       0.002378      16
# 4        0.005815         0.061778       0.814005      15

# %%
master_test=
# Out:
#        Unnamed: 0  votes_dem  votes_gop  total_votes   per_dem   per_gop  \
# 0               0    93003.0   130413.0     246588.0  0.377159  0.528870
# 1               1    93003.0   130413.0     246588.0  0.377159  0.528870
# 2               2    93003.0   130413.0     246588.0  0.377159  0.528870
# 3               3    93003.0   130413.0     246588.0  0.377159  0.528870
# 4               4    93003.0   130413.0     246588.0  0.377159  0.528870
# ...           ...        ...        ...          ...       ...       ...
# 10783        3137     7313.0     3920.0      12176.0  0.600608  0.321945
# 10784        3137     7313.0     3920.0      12176.0  0.600608  0.321945
# 10785        3138     1202.0     6154.0       8053.0  0.149261  0.764187
# 10786        3139      532.0     2911.0       3715.0  0.143203  0.783580
# 10787        3140      294.0     2898.0       3334.0  0.088182  0.869226
#
#          diff per_point_diff state_abbr      county_name  combined_fips  \
# ...
